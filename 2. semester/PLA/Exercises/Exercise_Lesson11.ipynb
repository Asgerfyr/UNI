# %% [markdown]
# # Lesson 11 Exercises

# %% [markdown]
# ## Exercise 1
# Find eigenvalues by hand of the following matrix
# $$
# A=
# \begin{bmatrix}
# -1 & 1\\
# -1 & 2
# \end{bmatrix}
# $$

# %% [markdown]
# ## Exercise 2
# Find by hand the associated eigenvectors of the eigenvalues calculated
#
# You may perform the normalization to unit vectors in numpy

# %% [markdown]
# ## Exercise 3
# As the example in the slides try to plot a sphere in 3-d. And the construct a symmetric $3\times 3$ matrix and plot the transform of the sphere by the symmetric matrix
# Insert the eigen vectors in the plot to see that the transformed sphere is an ellipsoid aligned with the eigen vectors.

# %% [markdown]
# ## Exercise 4
# Consider the matrix
# $$
# A=
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 1 & 2 & 1\\
# -1 & 0 & 1
# \end{bmatrix}
# $$
#
#
# 1. In numpy verify that A is not symmetric
# 2. Calculate the eigen values and eigen vectors
# 3. Verify that the eigenvectors are not orthogonal
# 4. Diagonalize the matrix and validate that it is the same as A

# %% [markdown]
# ## Exercise 5
# Consider any symmetric matrix say $B$
# $$
# B=
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 1 & 2\\
# 3 & 2 & 7
# \end{bmatrix}
# $$
# 1. How is the characteristic polynomial calculated
# 2. How many real roots does it have
# 3. How many independent eigen vectors does it have
# 4. What characterizes the eigenvectors
#
# Answer these questions in writing and verify 2-4 in numpy

# %% [markdown]
# ## Exercise 6
#
# Prove that the eigenvectors of $A^{-1}$ are the same as the eigenvectors of A while the eigenvalues are $\lambda^{-1}$.
#
# The proof follow by writing out the eigendecomposition of $A$ and $A^{-1}$.
